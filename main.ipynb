# %% [markdown]
# # Backrooms 24h survival

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %% [markdown]
# ## Data loading

# %%
backrooms_data = pd.read_csv('backrooms_24h.csv')
backrooms_data
# Out:
#        character_id  age     sex  height_cm  weight_kg  strength  reaction  \
# 0                 1   63    male        193         48         9         2
# 1                 2   26    male        189        130         7         1
# 2                 3   72  female        183         68         5         3
# 3                 4   32    male        143        129         2         1
# 4                 5   35  female        181         73        10         0
# ...             ...  ...     ...        ...        ...       ...       ...
# 19995         19996   49  female        182        119         3         5
# 19996         19997   79    male        149         95         0         2
# 19997         19998   16  female        175        106         7         6
# 19998         19999   51    male        202         99         7         5
# 19999         20000   32  female        188         51         6         1
#
#        stamina  speed  intelligence  ...  maze_complexity  geometry_stability  \
# 0            4      7            10  ...               67                  74
# 1            6      7             2  ...               64                  27
# 2            3      9             7  ...               69                  57
# 3            3      9            10  ...               83                  87
# 4           10      8             8  ...               54                  48
# ...        ...    ...           ...  ...              ...                 ...
# 19995        8      1             8  ...               55                  62
# 19996        5      0             7  ...               70                  41
# 19997        8      0             5  ...               60                  54
# 19998       10     10             7  ...               29                  73
# 19999        2      6             8  ...               64                  46
#
#            special_rule  spawn_area_danger  distance_to_nearest_entity  \
# 0        liminal_office                 44                          41
# 1              darkness                 59                          74
# 2        cave_isolation                 35                           5
# 3               neutral                 28                          75
# 4             trap_exit                 35                          25
# ...                 ...                ...                         ...
# 19995          flooding                 36                          42
# 19996    cave_isolation                 23                          89
# 19997    cave_isolation                 61                          83
# 19998          darkness                 48                          17
# 19999  mechanical_noise                 42                          93
#
#        noise_generated  time_since_last_encounter  survived_24h  \
# 0                   44                          8             1
# 1                   32                         10             1
# 2                   69                         12             1
# 3                   26                         24             0
# 4                   48                          4             0
# ...                ...                        ...           ...
# 19995               65                          7             1
# 19996               16                         19             1
# 19997               16                          5             0
# 19998               79                         23             0
# 19999               34                         16             0
#
#        survival_time_hours  escape_probability
# 0                       41               0.800
# 1                      110               0.653
# 2                       64               0.361
# 3                        0               0.173
# 4                        0               0.245
# ...                    ...                 ...
# 19995                   71               0.373
# 19996                   27               0.390
# 19997                    0               0.148
# 19998                    0               0.156
# 19999                    0               0.117
#
# [20000 rows x 50 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Data Preprocessing & Feature Engineering

# %% [markdown]
# ## Baseline model

# %% [markdown]
# ## Data Splitting

# %% [markdown]
# ## Modelling

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ## Feature Importance + Interpretantion

# %% [markdown]
# ## Error analysis

# %% [markdown]
# ## Conclusions & Next Steps
